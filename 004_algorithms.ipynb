# %%
from qiskit import *

# %%
circuit = QuantumCircuit(3, 3)

# %%
# %matplotlib inline
circuit.draw(output='mpl')

# %%
circuit.x(0)
circuit.barrier()
circuit.draw(output='mpl')

# %%
circuit.h(1)
circuit.cx(1,2)

# %%
circuit.draw(output='mpl')

# %%
circuit.cx
